# %%
base = [
    ("Я іду у школу.", "Я іду ў школу."),
    ("Я іду у лес.", "Я іду ў лес."),
    ("Я іду у парк.", "Я іду ў парк."),
    ("Я іду у магазін.", "Я іду ў магазін."),
    ("Я іду у дом.", "Я іду ў дом."),
    ("Я іду у бібліятэку.", "Я іду ў бібліятэку."),
    ("Я іду у універсітэт.", "Я іду ва ўніверсітэт."),
    ("Я іду у горад.", "Я іду ў горад."),

    ("Ён жыве у Мінску.", "Ён жыве ў Мінску."),
    ("Ён жыве у Гомелі.", "Ён жыве ў Гомелі."),
    ("Ён жыве у Гродне.", "Ён жыве ў Гродне."),
    ("Ён жыве у Віцебску.", "Ён жыве ў Віцебску."),
    ("Ён жыве у Магілёве.", "Ён жыве ў Магілёве."),

    ("Мы едзем у школу.", "Мы едзем у школу."),
    ("Мы едзем у дом.", "Мы едзем у дом."),
    ("Мы едзем у парк.", "Мы едзем у парк."),
    ("Мы едзем у горад.", "Мы едзем у горад."),
    ("Мы едзем у універсітэт.", "Мы едзем ва ўніверсітэт."),

    ("Ён вярнуўся у школу.", "Ён вярнуўся ў школу."),
    ("Ён пайшоў у лес.", "Ён пайшоў у лес."),
    ("Ён пайшоў у парк.", "Ён пайшоў у парк."),

    ("Я сяджу у класе.", "Я сяджу ў класе."),
    ("Я гляджу у акно.", "Я гляджу ў акно."),
    ("Я вяртаюся у дом.", "Я вяртаюся ў дом."),

    ("Ён працуе у школе.", "Ён працуе ў школе."),
    ("Ён вучацца у універсітэце.", "Ён вучыцца ва ўніверсітэце."),

    ("Я паехаў у Мінск.", "Я паехаў у Мінск."),
]

# %%
# !pip install -q transformers datasets accelerate sentencepiece
# Out:
# "pip" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "sdadas/byt5-text-correction"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import torch
#       2 from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
#       3
#       4 model_name = "sdadas/byt5-text-correction"
#
# ModuleNotFoundError: No module named 'torch'

# %%
from datasets import Dataset

dataset = Dataset.from_dict({
    "input_text": [x[0] for x in base],
    "target_text": [x[1] for x in base]
}).train_test_split(test_size=0.2)
